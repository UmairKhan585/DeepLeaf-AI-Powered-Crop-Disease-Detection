# %% [markdown]
# # Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score
from keras.models import load_model
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from IPython.display import display
import itertools

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# 2024-04-28 10:31:45.727046: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-28 10:31:45.727089: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-28 10:31:45.728449: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Image Data Loading Function

# %%
def load_data(data_dir, target_size=(224, 224), batch_size=32, shuffle=True):
    datagen = ImageDataGenerator(rescale=1./255)
    data_generator = datagen.flow_from_directory(
        data_dir,
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=shuffle 
    )
    return data_generator

# %% [markdown]
# # EfficientNet-B0 Model Creation Function

# %%
def create_model(input_shape, num_classes, learning_rate=0.001):
    base_model = tf.keras.applications.EfficientNetB0(weights='imagenet', include_top=False, input_shape=input_shape)
    x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
    x = tf.keras.layers.Dropout(0.5)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=base_model.input, outputs=outputs)
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %% [markdown]
# # Model Training Function with Callbacks

# %%
def train_model(model, train_generator, val_generator, epochs=30):
    model_checkpoint = ModelCheckpoint("My_Aug-Efficient-B0.keras", monitor='val_accuracy', save_best_only=True, mode='auto', verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
    history = model.fit(train_generator, validation_data=val_generator, epochs=epochs, callbacks=[model_checkpoint, reduce_lr])
    return history

# %% [markdown]
# # Model Evaluation Function

# %%
def evaluate_model(model, test_generator):
    loss, acc = model.evaluate(test_generator, verbose=0)
    print("Test Accuracy:", np.round(acc * 100, 2))
    return loss, acc

# %% [markdown]
# # Confusion Matrix Plotting Function

# %%
def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    thresh = cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], 'd'), horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %% [markdown]
# # Function for Predicting Random Image

# %%
def predict_random_image(model, test_generator, class_names):
    num_test_samples = len(test_generator.filenames)
    random_index = np.random.randint(0, num_test_samples)

    random_image_path = test_generator.filepaths[random_index]
    random_image = cv2.imread(random_image_path)
    random_image = cv2.cvtColor(random_image, cv2.COLOR_BGR2RGB)
    random_image = cv2.resize(random_image, (224, 224))
    random_image = random_image.astype('float32') / 255.0

    plt.imshow(random_image)
    plt.axis('off')
    plt.title("Random Image to Predict")
    plt.show()

    true_label = test_generator.filenames[random_index]
    print("Actual label:", true_label)

    prediction_prob = model.predict(np.expand_dims(random_image, axis=0))
    predicted_label_index = np.argmax(prediction_prob)
    
    class_names = list(class_names)  
    predicted_label = class_names[predicted_label_index]
    print("Predicted label:", predicted_label)

# %% [markdown]
# # Data Loading and Preprocessing Pipeline

# %%
train_generator = load_data("/kaggle/input/myrice-diseasesfinalize-aug/Augmented-Ds/train")
val_generator = load_data("/kaggle/input/myrice-diseasesfinalize-aug/Augmented-Ds/val")
test_generator = load_data("/kaggle/input/myrice-diseasesfinalize-aug/Augmented-Ds/test", shuffle=False)
# Out:
# Found 10245 images belonging to 4 classes.
# Found 406 images belonging to 4 classes.
# Found 411 images belonging to 4 classes.

# %% [markdown]
# # Model Creation and Training

# %%
model = create_model((224, 224, 3), num_classes=len(train_generator.class_indices), learning_rate=0.001)
history = train_model(model, train_generator, val_generator)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714300466.292744     183 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1714300466.406170     183 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 166/321 ━━━━━━━━━━━━━━━━━━━━ 2:35 1s/step - accuracy: 0.7122 - loss: 0.6757
# W0000 00:00:1714300631.856935     183 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.7470 - loss: 0.6047
# W0000 00:00:1714300745.034803     186 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_accuracy improved from -inf to 0.30542, saving model to My_Aug-Efficient-B0.keras
# W0000 00:00:1714300763.226632     183 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 400s 930ms/step - accuracy: 0.7472 - loss: 0.6044 - val_accuracy: 0.3054 - val_loss: 1.2328 - learning_rate: 0.0010
# Epoch 2/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.8701 - loss: 0.3527
# Epoch 2: val_accuracy improved from 0.30542 to 0.62315, saving model to My_Aug-Efficient-B0.keras
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 168s 514ms/step - accuracy: 0.8701 - loss: 0.3526 - val_accuracy: 0.6232 - val_loss: 1.1850 - learning_rate: 0.0010
# Epoch 3/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.9106 - loss: 0.2582
# Epoch 3: val_accuracy improved from 0.62315 to 0.77094, saving model to My_Aug-Efficient-B0.keras
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 169s 517ms/step - accuracy: 0.9106 - loss: 0.2582 - val_accuracy: 0.7709 - val_loss: 0.8820 - learning_rate: 0.0010
# Epoch 4/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.9105 - loss: 0.2619
# Epoch 4: val_accuracy improved from 0.77094 to 0.91626, saving model to My_Aug-Efficient-B0.keras
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 167s 508ms/step - accuracy: 0.9105 - loss: 0.2618 - val_accuracy: 0.9163 - val_loss: 0.3030 - learning_rate: 0.0010
# Epoch 5/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.9319 - loss: 0.1901
# Epoch 5: val_accuracy did not improve from 0.91626
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 168s 513ms/step - accuracy: 0.9319 - loss: 0.1901 - val_accuracy: 0.8005 - val_loss: 0.5888 - learning_rate: 0.0010
# Epoch 6/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.9488 - loss: 0.1409
# Epoch 6: val_accuracy did not improve from 0.91626
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 173s 527ms/step - accuracy: 0.9488 - loss: 0.1409 - val_accuracy: 0.8498 - val_loss: 0.4113 - learning_rate: 0.0010
# Epoch 7/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.9559 - loss: 0.1248
# Epoch 7: val_accuracy did not improve from 0.91626
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 178s 542ms/step - accuracy: 0.9559 - loss: 0.1248 - val_accuracy: 0.7611 - val_loss: 0.8316 - learning_rate: 0.0010
# Epoch 8/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.9707 - loss: 0.0822
# Epoch 8: val_accuracy improved from 0.91626 to 0.94828, saving model to My_Aug-Efficient-B0.keras
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 170s 518ms/step - accuracy: 0.9708 - loss: 0.0822 - val_accuracy: 0.9483 - val_loss: 0.1942 - learning_rate: 5.0000e-04
# Epoch 9/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.9862 - loss: 0.0418
# Epoch 9: val_accuracy did not improve from 0.94828
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 171s 523ms/step - accuracy: 0.9862 - loss: 0.0418 - val_accuracy: 0.9138 - val_loss: 0.3311 - learning_rate: 5.0000e-04
# Epoch 10/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.9861 - loss: 0.0377
# Epoch 10: val_accuracy did not improve from 0.94828
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 169s 515ms/step - accuracy: 0.9861 - loss: 0.0377 - val_accuracy: 0.9163 - val_loss: 0.2803 - learning_rate: 5.0000e-04
# Epoch 11/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.9898 - loss: 0.0309
# Epoch 11: val_accuracy did not improve from 0.94828
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 169s 517ms/step - accuracy: 0.9898 - loss: 0.0309 - val_accuracy: 0.8990 - val_loss: 0.3572 - learning_rate: 5.0000e-04
# Epoch 12/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9912 - loss: 0.0329
# Epoch 12: val_accuracy did not improve from 0.94828
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 202s 513ms/step - accuracy: 0.9912 - loss: 0.0329 - val_accuracy: 0.9335 - val_loss: 0.2586 - learning_rate: 2.5000e-04
# Epoch 13/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.9938 - loss: 0.0203
# Epoch 13: val_accuracy did not improve from 0.94828
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 166s 507ms/step - accuracy: 0.9938 - loss: 0.0203 - val_accuracy: 0.9039 - val_loss: 0.3574 - learning_rate: 2.5000e-04
# Epoch 14/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.9967 - loss: 0.0121
# Epoch 14: val_accuracy did not improve from 0.94828
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 166s 504ms/step - accuracy: 0.9967 - loss: 0.0121 - val_accuracy: 0.8990 - val_loss: 0.3426 - learning_rate: 2.5000e-04
# Epoch 15/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9966 - loss: 0.0117
# Epoch 15: val_accuracy did not improve from 0.94828
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 168s 513ms/step - accuracy: 0.9966 - loss: 0.0117 - val_accuracy: 0.9310 - val_loss: 0.2318 - learning_rate: 1.2500e-04
# Epoch 16/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9969 - loss: 0.0094
# Epoch 16: val_accuracy did not improve from 0.94828
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 168s 511ms/step - accuracy: 0.9969 - loss: 0.0094 - val_accuracy: 0.9360 - val_loss: 0.2277 - learning_rate: 1.2500e-04
# Epoch 17/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.9983 - loss: 0.0047
# Epoch 17: val_accuracy did not improve from 0.94828
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 167s 509ms/step - accuracy: 0.9983 - loss: 0.0047 - val_accuracy: 0.9384 - val_loss: 0.2592 - learning_rate: 1.2500e-04
# Epoch 18/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.9987 - loss: 0.0051
# Epoch 18: val_accuracy did not improve from 0.94828
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 168s 511ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 0.9483 - val_loss: 0.2266 - learning_rate: 6.2500e-05
# Epoch 19/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.9990 - loss: 0.0035
# Epoch 19: val_accuracy improved from 0.94828 to 0.95074, saving model to My_Aug-Efficient-B0.keras
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 169s 517ms/step - accuracy: 0.9990 - loss: 0.0035 - val_accuracy: 0.9507 - val_loss: 0.2279 - learning_rate: 6.2500e-05
# Epoch 20/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.9987 - loss: 0.0039
# Epoch 20: val_accuracy did not improve from 0.95074
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 170s 519ms/step - accuracy: 0.9987 - loss: 0.0039 - val_accuracy: 0.9507 - val_loss: 0.2423 - learning_rate: 6.2500e-05
# Epoch 21/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9984 - loss: 0.0048
# Epoch 21: val_accuracy improved from 0.95074 to 0.96059, saving model to My_Aug-Efficient-B0.keras
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 169s 515ms/step - accuracy: 0.9984 - loss: 0.0048 - val_accuracy: 0.9606 - val_loss: 0.2104 - learning_rate: 6.2500e-05
# Epoch 22/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.9991 - loss: 0.0035
# Epoch 22: val_accuracy did not improve from 0.96059
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 172s 523ms/step - accuracy: 0.9991 - loss: 0.0035 - val_accuracy: 0.9335 - val_loss: 0.2945 - learning_rate: 6.2500e-05
# Epoch 23/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.9986 - loss: 0.0041
# Epoch 23: val_accuracy did not improve from 0.96059
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 170s 517ms/step - accuracy: 0.9986 - loss: 0.0041 - val_accuracy: 0.9557 - val_loss: 0.2205 - learning_rate: 6.2500e-05
# Epoch 24/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.9992 - loss: 0.0034
# Epoch 24: val_accuracy did not improve from 0.96059
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 172s 526ms/step - accuracy: 0.9992 - loss: 0.0034 - val_accuracy: 0.9532 - val_loss: 0.2240 - learning_rate: 6.2500e-05
# Epoch 25/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9986 - loss: 0.0038
# Epoch 25: val_accuracy did not improve from 0.96059
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 168s 513ms/step - accuracy: 0.9986 - loss: 0.0038 - val_accuracy: 0.9507 - val_loss: 0.2327 - learning_rate: 3.1250e-05
# Epoch 26/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.9984 - loss: 0.0042
# Epoch 26: val_accuracy did not improve from 0.96059
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 166s 506ms/step - accuracy: 0.9984 - loss: 0.0042 - val_accuracy: 0.9557 - val_loss: 0.2200 - learning_rate: 3.1250e-05
# Epoch 27/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.9987 - loss: 0.0041
# Epoch 27: val_accuracy did not improve from 0.96059
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 167s 509ms/step - accuracy: 0.9987 - loss: 0.0041 - val_accuracy: 0.9557 - val_loss: 0.2145 - learning_rate: 3.1250e-05
# Epoch 28/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.9991 - loss: 0.0049
# Epoch 28: val_accuracy did not improve from 0.96059
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 168s 513ms/step - accuracy: 0.9991 - loss: 0.0049 - val_accuracy: 0.9557 - val_loss: 0.2213 - learning_rate: 1.5625e-05
# Epoch 29/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.9993 - loss: 0.0031
# Epoch 29: val_accuracy did not improve from 0.96059
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 170s 519ms/step - accuracy: 0.9993 - loss: 0.0031 - val_accuracy: 0.9532 - val_loss: 0.2264 - learning_rate: 1.5625e-05
# Epoch 30/30
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.9991 - loss: 0.0046
# Epoch 30: val_accuracy did not improve from 0.96059
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 170s 518ms/step - accuracy: 0.9991 - loss: 0.0046 - val_accuracy: 0.9581 - val_loss: 0.2170 - learning_rate: 1.5625e-05

# %% [markdown]
# # Save the Model

# %%
model.save("/kaggle/working/My_Aug-Efficient-B0.h5")

# %% [markdown]
# # Evaluate Model Performance on Original-Ds Test set

# %%
loss, acc = evaluate_model(model, test_generator)
# Out:
# Test Accuracy: 95.62
# W0000 00:00:1714305837.637020     186 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update

# %% [markdown]
# # Training History Visualization

# %%
plt.plot(history.history['accuracy'], label='Train Set')
plt.plot(history.history['val_accuracy'], label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.show()

plt.plot(history.history['loss'], label='Train Set')
plt.plot(history.history['val_loss'], label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.show()

# %% [markdown]
# # Evaluate Model Predictions and Metrics

# %%
test_pred_prob = model.predict(test_generator)
test_pred_labels = np.argmax(test_pred_prob, axis=1)
test_true_labels = test_generator.classes
class_names = list(train_generator.class_indices.keys())
print(classification_report(test_true_labels, test_pred_labels, target_names=class_names))
# Out:
#  5/13 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# W0000 00:00:1714305860.799746     186 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step
#                 precision    recall  f1-score   support
#
# Rice_BrownSpot       0.92      0.95      0.94        62
#   Rice_Healthy       0.99      0.94      0.96       150
# Rice_LeafBlast       0.89      0.94      0.92        99
# Rice_NeckBlast       1.00      1.00      1.00       100
#
#       accuracy                           0.96       411
#      macro avg       0.95      0.96      0.95       411
#   weighted avg       0.96      0.96      0.96       411
# W0000 00:00:1714305873.466808     186 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update

# %% [markdown]
# # Confusion Matrix Visualization

# %%
conf_matrix = confusion_matrix(test_true_labels, test_pred_labels)
plot_confusion_matrix(conf_matrix, target_names=class_names)

# %% [markdown]
# # Additional Evaluation Metrics Calculation and Printing

# %%
precision = precision_score(test_true_labels, test_pred_labels, average='weighted')
recall = recall_score(test_true_labels, test_pred_labels, average='weighted')
f1_score = f1_score(test_true_labels, test_pred_labels, average='weighted')
TP = conf_matrix[1][1]
TN = conf_matrix[0][0]
FP = conf_matrix[0][1]
FN = conf_matrix[1][0]
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)

# Print evaluation measures
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1_score)
print("Sensitivity:", sensitivity)
print("Specificity:", specificity)
# Out:
# Precision: 0.9576330755619077
# Recall: 0.9562043795620438
# F1 Score: 0.9565485458686065
# Sensitivity: 0.9929577464788732
# Specificity: 1.0

# %% [markdown]
# # Predict on a Random Image from Original-Ds

# %%
predict_random_image(model, test_generator, train_generator.class_indices.keys())
# Out:
# Actual label: Rice_NeckBlast/IMG20201109182008_00.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# Predicted label: Rice_NeckBlast
